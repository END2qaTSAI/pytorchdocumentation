# %%
# !pip install -U transformers==3.0.0
# Out:
# Collecting transformers==3.0.0
#   Downloading transformers-3.0.0-py3-none-any.whl (754 kB)
#      |████████████████████████████████| 754 kB 9.0 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (2019.12.20)
# Collecting tokenizers==0.8.0-rc4
#   Downloading tokenizers-0.8.0rc4-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 42.5 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (1.19.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (21.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (4.62.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 37.2 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.0) (3.0.12)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 66.8 MB/s
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3.0.0) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.0) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.0) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.0) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.0) (1.0.1)
# Installing collected packages: tokenizers, sentencepiece, sacremoses, transformers
# Successfully installed sacremoses-0.0.45 sentencepiece-0.1.96 tokenizers-0.8.0rc4 transformers-3.0.0

# %%
# !python -m nltk.downloader punkt
# Out:
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !git clone https://github.com/patil-suraj/question_generation.git
# Out:
# Cloning into 'question_generation'...
# remote: Enumerating objects: 265, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 265 (delta 100), reused 95 (delta 95), pack-reused 156
# Receiving objects: 100% (265/265), 289.06 KiB | 12.04 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
text = "PyTorch documentation — PyTorch 1.9.0 documentation."

# %% [markdown]
# ## Single task QA

# %%
text2 = """PyTorch is an optimized tensor library for deep learning using GPUs and CPUs.
Features described in this documentation are classified by release status:
Stable:  These features will be maintained long-term and there should generally
be no major performance limitations or gaps in documentation.
We also expect to maintain backwards compatibility (although
breaking changes can happen and notice will be given one release ahead
of time).
Beta:  These features are tagged as Beta because the API may change based on
user feedback, because the performance needs to improve, or because
coverage across operators is not yet complete. For Beta features, we are
committing to seeing the feature through to the Stable classification.
We are not, however, committing to backwards compatibility.
Prototype:  These features are typically not available as part of
binary distributions like PyPI or Conda, except sometimes behind run-time
flags, and are at an early stage for feedback and testing.
Notes
Language Bindings
Python API
Libraries
Community
Index
Module Inde"""

# %%
# %cd question_generation
# Out:
# /content/question_generation

# %%
from pipelines import pipeline

# %%
nlp = pipeline("question-generation")
# Out:
# Downloading:   0%|          | 0.00/627 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/656 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242M [00:00<?, ?B/s]

# %%
nlp(text3)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# [{'answer': 'Automatic Mixed Precision',
#   'question': 'What type of examples are examples of?'}]

# %% [markdown]
# If you want to use the t5-base model, then pass the path through model parameter

# %%
nlp = pipeline("question-generation", model="valhalla/t5-base-qg-hl")
# Out:
# Downloading:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/15.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/129 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %%
nlp(text3)
# Out:
# [{'answer': 'Automatic Mixed Precision',
#   'question': 'What type of precision is an example of?'}]

# %%
nlp(text4)
# Out:
# [{'answer': 'Stable',
#   'question': 'What is the classification of the features that will be maintained long-term?'},
#  {'answer': 'backwards compatibility',
#   'question': 'What do we expect to maintain?'},
#  {'answer': 'the Stable classification',
#   'question': 'What classification are Beta features committed to seeing through?'},
#  {'answer': 'feedback and testing',
#   'question': 'What are prototype features at an early stage for?'}]

# %%
nlp(text2)
# Out:
# [{'answer': 'PyTorch',
#   'question': 'What is an optimized tensor library for deep learning using GPUs and CPUs?'},
#  {'answer': 'Stable',
#   'question': 'What classification does PyTorch feature belong to?'},
#  {'answer': 'backwards compatibility',
#   'question': 'What do we expect to maintain?'},
#  {'answer': 'Beta',
#   'question': 'What type of feature is tagged as Beta because the API may change based on user feedback?'},
#  {'answer': 'Stable classification',
#   'question': 'What classification does PyTorch commit to seeing Beta features through?'},
#  {'answer': 'backwards compatibility',
#   'question': 'What are we not committing to?'},
#  {'answer': 'Prototype',
#   'question': 'What features are typically not available as part of binary distributions like PyPI or Conda?'},
#  {'answer': 'Python API Libraries Community Index Module Inde',
#   'question': 'What is a language binding for PyTorch?'}]

# %% [markdown]
# ## Multitask QA-QG

# %% [markdown]
# ### small-model

# %%
nlp = pipeline("multitask-qa-qg")

# %% [markdown]
# #### QG

# %%
nlp(text)
# Out:
# [{'answer': 'Python',
#   'question': 'What is an interpreted, high-level, general-purpose programming language?'},
#  {'answer': 'Guido van Rossum', 'question': 'Who created Python?'}]

# %%
nlp(text2)
# Out:
# [{'answer': 'PyTorch',
#   'question': 'What is an optimized tensor library for deep learning?'},
#  {'answer': 'Stable',
#   'question': 'What is the name of the release status of PyTorch?'},
#  {'answer': 'backwards compatibility',
#   'question': 'What does PyTorch expect to maintain?'},
#  {'answer': 'Beta',
#   'question': 'What feature is tagged as Beta because the API may change based on user feedback?'},
#  {'answer': 'Stable classification',
#   'question': 'What is a feature we are committing to seeing through to for Beta features?'},
#  {'answer': 'backwards compatibility',
#   'question': 'What are we not committing to for Beta features?'},
#  {'answer': 'Prototype',
#   'question': 'What feature is typically not available as part of binary distributions like PyPI or Conda?'},
#  {'answer': 'Python API Libraries Community Index Module Inde',
#   'question': 'What is the name of the Language Bindings?'}]

# %%
nlp(text4)
# Out:
# [{'answer': 'Stable',
#   'question': 'What features will be maintained long-term and there should generally be no major performance limitations or gaps in documentation?'},
#  {'answer': 'backwards compatibility',
#   'question': 'What does Stable expect to maintain?'},
#  {'answer': 'the Stable classification',
#   'question': 'What is a feature we are committing to seeing through to for Beta features?'},
#  {'answer': 'feedback and testing',
#   'question': 'What are these features at an early stage for?'}]

# %% [markdown]
# #### QA

# %%
nlp({
  "question": "Who created Python ?",
  "context": text
})
# Out:
# 'Guido van Rossum'

# %%
nlp({
    "question": "Who wrote Forrest Gump ?",
     "context": text4
})
# Out:
# 'Paul'

# %% [markdown]
# ### base-model

# %%
nlp = pipeline("multitask-qa-qg", model="valhalla/t5-base-qa-qg-hl")
# Out:
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %% [markdown]
# #### QG

# %%
nlp(text)
# Out:
# ['Who created Python?',
#  'When was Python first released?',
#  "What is Python's design philosophy?"]

# %%
nlp(text2)
# Out:
# ['What is PyTorch an optimized tensor library for?',
#  'What are features described in this documentation classified by?',
#  'Why are features tagged as Beta?']

# %%
nlp(text4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-37a8137d986e> in <module>()
# ----> 1 nlp(text4)
#
# /content/question_generation/pipelines.py in __call__(self, context, **generate_kwargs)
#     248             input_ids=inputs['input_ids'].to(self.device),
#     249             attention_mask=inputs['attention_mask'].to(self.device),
# --> 250             **generate_kwargs
#     251         )
#     252
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py in generate(self, input_ids, max_length, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, repetition_penalty, bad_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, num_return_sequences, attention_mask, decoder_start_token_id, use_cache, **model_specific_kwargs)
#    1227                 attention_mask=attention_mask,
#    1228                 use_cache=use_cache,
# -> 1229                 model_specific_kwargs=model_specific_kwargs,
#    1230             )
#    1231         else:
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py in _generate_beam_search(self, input_ids, cur_len, max_length, min_length, do_sample, early_stopping, temperature, top_k, top_p, repetition_penalty, no_repeat_ngram_size, bad_words_ids, pad_token_id, eos_token_id, batch_size, num_return_sequences, length_penalty, num_beams, vocab_size, encoder_outputs, attention_mask, use_cache, model_specific_kwargs)
#    1406                 input_ids, past=past, attention_mask=attention_mask, use_cache=use_cache, **model_specific_kwargs
#    1407             )
# -> 1408             outputs = self(**model_inputs)  # (batch_size * num_beams, cur_len, vocab_size)
#    1409             next_token_logits = outputs[0][:, -1, :]  # (batch_size * num_beams, vocab_size)
#    1410
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py in forward(self, input_ids, attention_mask, encoder_outputs, decoder_input_ids, decoder_attention_mask, decoder_past_key_value_states, use_cache, labels, inputs_embeds, decoder_inputs_embeds, head_mask, output_attentions, output_hidden_states, **kwargs)
#    1134             use_cache=use_cache,
#    1135             output_attentions=output_attentions,
# -> 1136             output_hidden_states=output_hidden_states,
#    1137         )
#    1138
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, past_key_value_states, use_cache, output_attentions, output_hidden_states)
#     746                 past_key_value_state=past_key_value_state,
#     747                 use_cache=use_cache,
# --> 748                 output_attentions=output_attentions,
#     749             )
#     750             # layer_outputs is a tuple with:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py in forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, head_mask, past_key_value_state, use_cache, output_attentions)
#     536                 query_length=query_length,
#     537                 use_cache=use_cache,
# --> 538                 output_attentions=output_attentions,
#     539             )
#     540             hidden_states = cross_attention_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py in forward(self, hidden_states, kv, attention_mask, position_bias, head_mask, past_key_value_state, use_cache, query_length, output_attentions)
#     448         output_attentions=False,
#     449     ):
# --> 450         norm_x = self.layer_norm(hidden_states)
#     451         attention_output = self.EncDecAttention(
#     452             norm_x,
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_t5.py in forward(self, x)
#     158         x = x / torch.sqrt(variance + self.variance_epsilon)
#     159
# --> 160         if self.weight.dtype == torch.float16:
#     161             x = x.to(torch.float16)
#     162         return self.weight * x
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1115             self._is_full_backward_hook = None
#    1116
# -> 1117     def __getattr__(self, name: str) -> Union[Tensor, 'Module']:
#    1118         if '_parameters' in self.__dict__:
#    1119             _parameters = self.__dict__['_parameters']
#
# KeyboardInterrupt:

# %% [markdown]
# #### QA

# %%
nlp({
  "question": "Who created Python ?",
  "context": text
})
# Out:
# 'Guido van Rossum'

# %%
nlp({
    "question": "Who wrote Forrest Gump ?",
     "context": text4
})
# Out:
# 'Forrest Gump'

# %% [markdown]
# ## End-to-End QG

# %% [markdown]
# ### small model

# %%
nlp = pipeline("e2e-qg")
# Out:
# Downloading:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242M [00:00<?, ?B/s]

# %%
nlp(text)
# Out:
# ['Who created Python?',
#  'When was Python first released?',
#  "What is Python's design philosophy?"]

# %%
nlp(text2)
# Out:
# ['What is an optimized tensor library for deep learning using GPUs and CPUs?',
#  'What is tagged as Beta because the API may change based on user feedback, or because coverage across operators is not yet complete?',
#  'Why are these features typically not available as part of binary distributions like PyPI or Conda?']

# %%
nlp(text4)
# Out:
# ['What is tagged as Beta because the API may change based on user feedback?',
#  'What is the name of the feature that we are committing to seeing through to the Stable classification?',
#  'Where are these features typically not available?']

# %% [markdown]
# ### base-model

# %%
nlp = pipeline("e2e-qg", model="valhalla/t5-base-e2e-qg")
# Out:
# Downloading:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/195 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %%
nlp(text)
# Out:
# ['Who created Python?',
#  'When was Python first released?',
#  "What is Python's design philosophy?"]

# %%
nlp(text2)
# Out:
# ['What is PyTorch an optimized tensor library for?',
#  'What are features described in this documentation classified by?',
#  'Why are features tagged as Beta?']

# %%
nlp(text4)
# Out:
# ['What will be maintained long-term and there should generally be no major performance limitations or gaps in documentation?',
#  'What is expected to maintain backwards compatibility?',
#  'Why are these features tagged as Beta?']
